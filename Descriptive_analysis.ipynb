# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
df = pd.read_csv('/content/bmw (1).csv')

# %%
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3       1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %% [markdown]
# Handling the missing value

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.drop_duplicates(inplace= True)

# %%
df.shape
# Out:
# (10664, 9)

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10664.000000   10664.000000   10664.000000  10664.000000  10664.000000
# mean    2017.062828   22692.888691   25710.978995    131.597431     56.483121
# std        2.350668   11434.921030   25146.634940     61.611394     31.465604
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14897.000000    5665.750000    135.000000     45.600000
# 50%     2017.000000   20261.500000   18783.000000    145.000000     53.300000
# 75%     2019.000000   27890.000000   38436.500000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10664.000000
# mean       2.170161
# std        0.552556
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %% [markdown]
# ## Univariate Analysis

# %%
df[['year','price','mileage','tax','mpg','engineSize']].describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10664.000000   10664.000000   10664.000000  10664.000000  10664.000000
# mean    2017.062828   22692.888691   25710.978995    131.597431     56.483121
# std        2.350668   11434.921030   25146.634940     61.611394     31.465604
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14897.000000    5665.750000    135.000000     45.600000
# 50%     2017.000000   20261.500000   18783.000000    145.000000     53.300000
# 75%     2019.000000   27890.000000   38436.500000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10664.000000
# mean       2.170161
# std        0.552556
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
df['price'].hist(bins = 100)
plt.title('distribution of price')
plt.show()

# %%
df['mileage'].hist(bins = 100)
plt.title('Mileage histogram')
plt.show()

# %%
df['mpg'].hist(bins =100)
plt.title('mpg histogram')
plt.show()

# %%
df.boxplot(column='price')
plt.title("Price Boxplot")
plt.show()

# %%
df.boxplot(column='mileage')
plt.title("mileage Boxplot")
plt.show()

# %%
df.boxplot(column='mpg')
plt.title("mpg Boxplot")
plt.show()

# %%
df['model'].value_counts().head(10)
# Out:
# model
# 3 Series    2434
# 1 Series    1962
# 2 Series    1188
# 5 Series    1051
# 4 Series     986
# X1           797
# X3           550
# X5           464
# X2           261
# X4           177
# Name: count, dtype: int64

# %%
df['transmission'].value_counts(normalize=True) * 100
# Out:
# transmission
# Semi-Auto    43.482746
# Automatic    33.214554
# Manual       23.302701
# Name: proportion, dtype: float64

# %%
df['fuelType'].value_counts()
# Out:
# fuelType
# Diesel      6988
# Petrol      3340
# Hybrid       297
# Other         36
# Electric       3
# Name: count, dtype: int64

# %%
df['fuelType'].value_counts().plot(kind='bar')
plt.title("Fuel Type Distribution")
plt.show()

# %%
df['model'].value_counts().plot(kind='bar')
plt.title("model Distribution")
plt.show()

# %%
df['transmission'].value_counts().plot(kind='bar')
plt.title("transmission Distribution")
plt.show()

# %%
df[['price','year','mileage','mpg','engineSize','tax']].corr()
# Out:
#                price      year   mileage       mpg  engineSize       tax
# price       1.000000  0.623754 -0.605473 -0.203986    0.461750  0.264178
# year        0.623754  1.000000 -0.772761 -0.070185   -0.022398  0.025393
# mileage    -0.605473 -0.772761  1.000000  0.117014   -0.006961 -0.171236
# mpg        -0.203986 -0.070185  0.117014  1.000000   -0.402058 -0.351837
# engineSize  0.461750 -0.022398 -0.006961 -0.402058    1.000000  0.431361
# tax         0.264178  0.025393 -0.171236 -0.351837    0.431361  1.000000

# %%
import seaborn as sns

sns.heatmap(df[['price','year','mileage','mpg','engineSize','tax']].corr(),
            annot=True, cmap='coolwarm')
plt.show()

# %%
df.groupby('fuelType')['price'].mean()
# Out:
# fuelType
# Diesel      21749.448769
# Electric    18466.000000
# Hybrid      27154.966330
# Other       18193.861111
# Petrol      24322.279940
# Name: price, dtype: float64

# %%
df.groupby('transmission')['price'].median()
# Out:
# transmission
# Automatic    19299.5
# Manual       13490.0
# Semi-Auto    24990.0
# Name: price, dtype: float64

# %%
df.boxplot(column='price', by='fuelType')
plt.title("Price by Fuel Type")
plt.suptitle("")
plt.show()

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['price'] < Q1 - 1.5*IQR) | (df['price'] > Q3 + 1.5*IQR)]
len(outliers)
# Out:
# 478
